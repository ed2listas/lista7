# %%
import csv 
import random


list_all = [] #list all the the subsets int the jobs    
all_final_result = [] 
table2 = []
last = []
#sum_best_schedule
all_jobs = []
    
class Job: 
    def __init__(self,name, start, finish, profit):
        self.name = name
        self.start  = start 
        self.finish = finish 
        self.profit  = profit 
  
  
def binarySearch(job, start_index): 
  
    lo = 0
    hi = start_index - 1
  
    # Perform binary Search iteratively 
    while lo <= hi: 
        mid = (lo + hi) // 2
        if job[mid].finish <= job[start_index].start: 
            if job[mid + 1].finish <= job[start_index].start: 
                lo = mid + 1
            else: 
                return mid 
        else: 
            hi = mid - 1
    return -1
  
def schedule(job): 
    
    job = sorted(job, key = lambda j: j.finish) 
    
    list_all.append(job[0].profit)
  
    n = len(job)  
    table = [0 for _ in range(n)] 
    
    table[0] = job[0].profit;
    
    aux = []
    first_include = 0
    last_include = 0
    
  
    for i in range(1, n): 
  
        inclProf = job[i].profit
        first_include = inclProf
        l = binarySearch(job, i) 

        if (l != -1): 
            inclProf += table[l];
            last_include = inclProf
  
        table[i] = max(inclProf, table[i - 1]) 
        
        if(table[i] != table[i - 1]):
            aux.append(first_include)
            aux.append(last_include - first_include)
            list_all.append(aux)
        
        aux = []

    print("Soma dos pesos do melhor intervalo %d" %(table[n - 1]))  
    
    return table 

def verify_number():
    cont = 0
    for i in last:
        for j in table2:
            cont+=1
            if(i == j):
                for k in list_all[cont - 1]:
                    all_final_result.append(k)
                
        cont = 0
        
def verify_number2():
    aux = []
    cont = 0
    global all_final_result
    for i in all_final_result:
        for j in table2:
            cont+= 1
            if(i == j):
                all_final_result.remove(i)
                all_final_result = all_final_result + list_all[cont - 1]

        cont = 0

def remove_duplicate(list_number):
    l = []
    for i in list_number:
        if i not in l:
            l.append(i)
    l.sort()
    return l
            

with open("jobs.csv", "r") as f:
    data = csv.reader(f)
    next(data)

    for line in data:
        all_jobs.append(Job(line[0], int(line[1]), int(line[2]), int(line[3])))
  
    job = random.sample(all_jobs, 15)
    
#job = [Job("Job1",1, 2, 50), Job("Job2",3, 5, 20),Job("Job3",6, 19, 100), Job("Job4",2, 100, 200)] 

#job = [ Job("Job1",2,3,15), Job("Job2",0,1,3), Job("Job3",0,5,9), Job("Job4",3,6,1), Job("Job5",4,7,11),
 #      Job("Job6",3,9,5), Job("Job7",5,10,8), Job("Job8",8,10,7)]

#job = [Job(0, 6, 3),Job(1, 4, 5),Job(3, 5, 5),Job(3, 8, 8),Job(4, 7, 3),Job(5, 9, 7),Job(6, 10, 3),Job(8, 11, 4)]

table = schedule(job) 

#for i in list_all:
#    print(i)
#print(table)

table2 = remove_repetidos(table)

#print(table2)

last = list_all[-1]


#print(last)
all_final_result.append(last[0])


here = []
here.append(list_all[0])
list_all[0] = here

verify_number()
#print(all_final_result)
verify_number2()
verify_number2()
verify_number2()
verify_number2()

final_not_duplicate = []

final_not_duplicate = remove_repetidos(all_final_result)

#print(final_not_duplicate)

print ("[") 
for i in final_not_duplicate:
    for j in job:
        if(i == j.profit):
            print("(" + j.name + ", começo: " + str(j.start) + ", fim: "+ str(j.finish) + ", peso: " + str(j.profit)+ ")" )
print ("]") 

#print(list_all)
# Out:
# Soma dos pesos do melhor intervalo 91
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-81390b537176> in <module>()
#     129 #print(table)
#     130
# --> 131 table2 = remove_repetidos(table)
#     132
#     133 #print(table2)
#
# NameError: name 'remove_repetidos' is not defined

# %%
import random

def longest_sequence_increase(size):
    list_number  = []
    vector_count = []
    final_solution = []
    final = []


    for i in range(size):
        vector_count.append(1)
        final_solution.append(i)

    list_number = random.sample(range(1,size +60 ), size)

    for i in range(0,len(list_number)):
        for j in range(0, i): 
            if(list_number[i] > list_number[j] and vector_count[j] + 1 > vector_count[i]):
                vector_count[i] = vector_count[j] + 1
                final_solution[i] = j


    indice_max = 0 
    for i in range(0, len(vector_count)):
        if(vector_count[i] > vector_count[indice_max]):
            indice_max = i

    t = indice_max;
    newT = indice_max;

    t = newT
    final.append(list_number[t])
    newT = final_solution[t]
    while(t != newT):
        t = newT
        final.append(list_number[t])
        newT = final_solution[t]
    final.sort()



    print("vetor atual: ")
    print(list_number)
    print("")
    print("Maior subsequencia crescente: ")
    print(final)
    
print("\n--------vetor com 8--------------")
longest_sequence_increase(8)

print("\n--------vetor com 16--------------")
longest_sequence_increase(16)

print("\n--------vetor com 100--------------")
longest_sequence_increase(100)

print("\n--------vetor com 250--------------")
longest_sequence_increase(250)

print("\n--------vetor com 5000--------------")
#longest_sequence_increase(5000)
# Out:
# --------vetor com 8--------------
# vetor atual:
# [45, 25, 26, 27, 49, 16, 33, 56]
#
# Maior subsequencia crescente:
# [25, 26, 27, 49, 56]
#
# --------vetor com 16--------------
# vetor atual:
# [11, 57, 14, 2, 55, 29, 42, 16, 54, 28, 12, 59, 19, 48, 3, 23]
#
# Maior subsequencia crescente:
# [11, 14, 29, 42, 54, 59]
#
# --------vetor com 100--------------
# vetor atual:
# [111, 148, 46, 130, 54, 24, 159, 28, 102, 21, 30, 124, 43, 152, 29, 112, 154, 131, 42, 70, 157, 25, 45, 36, 59, 143, 156, 147, 122, 14, 78, 5, 85, 72, 110, 48, 109, 108, 11, 44, 18, 40, 35, 81, 141, 144, 38, 3, 34, 107, 39, 62, 103, 94, 106, 26, 117, 60, 50, 113, 13, 93, 20, 41, 136, 6, 84, 23, 75, 97, 123, 67, 7, 158, 133, 150, 86, 77, 69, 132, 100, 142, 52, 58, 80, 61, 51, 153, 92, 71, 90, 145, 19, 129, 32, 101, 12, 63, 146, 68]
#
# Maior subsequencia crescente:
# [24, 28, 30, 43, 45, 59, 78, 85, 103, 106, 117, 123, 133, 142, 145, 146]
#
# --------vetor com 250--------------
# vetor atual:
# [102, 60, 227, 152, 148, 195, 139, 264, 12, 141, 40, 267, 98, 189, 113, 182, 8, 87, 95, 228, 32, 26, 19, 159, 71, 158, 218, 248, 169, 192, 65, 259, 6, 184, 97, 73, 263, 110, 190, 276, 84, 180, 293, 94, 174, 138, 146, 177, 14, 68, 124, 114, 163, 198, 170, 149, 129, 247, 103, 115, 160, 290, 121, 151, 281, 231, 54, 90, 62, 244, 272, 274, 203, 221, 46, 234, 164, 16, 78, 125, 144, 42, 133, 33, 10, 287, 36, 232, 147, 252, 299, 75, 127, 179, 99, 24, 295, 61, 175, 206, 96, 142, 262, 162, 215, 246, 66, 243, 176, 85, 210, 302, 130, 44, 5, 265, 153, 107, 126, 168, 283, 266, 59, 48, 235, 154, 200, 132, 204, 291, 93, 280, 35, 242, 13, 23, 191, 136, 305, 199, 279, 20, 245, 109, 173, 186, 131, 91, 251, 74, 41, 209, 294, 229, 112, 273, 29, 224, 241, 81, 286, 49, 181, 270, 300, 134, 135, 269, 137, 11, 223, 86, 64, 219, 172, 309, 34, 187, 140, 275, 116, 308, 253, 271, 76, 82, 58, 196, 208, 108, 303, 304, 216, 166, 226, 278, 225, 69, 25, 211, 156, 161, 201, 183, 282, 145, 51, 288, 301, 57, 79, 220, 104, 2, 188, 3, 101, 277, 258, 307, 100, 260, 150, 43, 207, 222, 167, 106, 9, 250, 53, 239, 88, 21, 17, 92, 193, 289, 118, 296, 178, 230, 284, 236, 213, 214, 7, 254, 52, 157]
#
# Maior subsequencia crescente:
# [12, 40, 87, 95, 97, 110, 114, 115, 121, 125, 127, 130, 132, 134, 135, 137, 172, 187, 196, 208, 216, 226, 278, 282, 288, 301, 307]
#
# --------vetor com 5000--------------
